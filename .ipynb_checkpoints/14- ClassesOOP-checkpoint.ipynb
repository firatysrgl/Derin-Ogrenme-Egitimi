# %%
class Person():
    # Property [Özellikler]
    name = ""
    age = 0
    gender = ""

    # Method initalizer
    def __init__(self,name,age,gender):
        self.name = name
        self.age = age
        self.gender = gender

# %%
user = Person ("Fırat",21,"Erkek")

# %%
user.age
# Out:
# 21

# %%
user.gender
# Out:
# 'Erkek'

# %%
user.name
# Out:
# 'Fırat'

# %%
class Dog ():
    year = 7
    def __init__ (self,age=5):
        self.age = age
        self.dogHumanAge= age * self.year
        print ("dog instance")

        
    def humanAge(self):
        return self.age * self.year

# %%
myDog = Dog (3)
# Out:
# dog instance

# %%
myDog.age
# Out:
# 3

# %%
myDog.humanAge()
# Out:
# 21

# %%
barley = Dog ()
# Out:
# dog instance

# %%
barley.dogHumanAge
# Out:
# 35
