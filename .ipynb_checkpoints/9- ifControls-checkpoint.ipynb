# %%
x=5
y=2

# %%
x>y
# Out:
# True

# %%
 x<y
# Out:
# False

# %%
y = 5

# %%
x>=y
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
 not 1==1
# Out:
# False

# %%
not 2==1
# Out:
# True

# %%
 10 in [10,20,30] # in içinde var mı diye sorgular
# Out:
# True

# %%
5 not in [10,20,30] # not in içinde yok mu diye sorgular
# Out:
# True

# %%
 10 in {10,20,30}
# Out:
# True

# %%
my_dictionary = {"a":10,"b":20,"c":30}

# %%
10 in my_dictionary
# Out:
# False

# %%
10 in my_dictionary.values()
# Out:
# True

# %%
"b" in my_dictionary.keys()
# Out:
# True

# %%
my_super_hero = "Batman"

# %%
my_super_hero == "Batman"
# Out:
# True

# %%
my_super_hero == "Superman"
# Out:
# False

# %%
if my_super_hero == "Batman":
    #indentation [ if kullanınca otomatik bu boşluk oluşur. bu boşluğu silip veya devam eden satırlarda bu boşluğu silip satır başından devam edersek if bloğunun dışına çıkmış oluruz.]
    print ("my superhero is batman")
    print ("aaaaa")
############------------------########
print ("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
# Out:
# my superhero is batman
# aaaaa
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
if my_super_hero == "Superman":
    print ("my superhero is superman")
print ("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
# Out:
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
if 3<4:
    print ("hello world")
    print ("Fırat")
# Out:
# hello world
# Fırat

# %%
if 3>4:
    print ("hello world")
    print ("Fırat")

# %%
car = input ("Araç Markası Giriniz: ")
# Out:
# Araç Markası Giriniz:  opel

# %%
if car == "opel":
    print ("OPEL")
elif car == "mazda":
    print ("MAZDA")
elif car == "volvo":
    print ("VOLVO")
elif car == "honda":
    print ("HONDA")
else:
    print ("verilen araba markası bulunamadı")
# Out:
# OPEL

# %%
myCarList = ["opel","mazda","volvo","honda"]

# %%
if car in myCarList :
    print (":)")
else:
    print (":(")
# Out:
# :)
