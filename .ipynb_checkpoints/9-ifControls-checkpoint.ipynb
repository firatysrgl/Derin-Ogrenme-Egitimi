# %%
x=5
y=2

# %%
x>y
# Out:
# True

# %%
 x<y
# Out:
# False

# %%
y = 5

# %%
x>=y
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
 not 1==1
# Out:
# False

# %%
not 2==1
# Out:
# True

# %%
 10 in [10,20,30] # in içinde var mı diye sorgular
# Out:
# True

# %%
5 not in [10,20,30] # not in içinde yok mu diye sorgular
# Out:
# True

# %%
 10 in {10,20,30}
# Out:
# True

# %%
my_dictionary = {"a":10,"b":20,"c":30}

# %%
10 in my_dictionary
# Out:
# False

# %%
10 in my_dictionary.values()
# Out:
# True

# %%
"b" in my_dictionary.keys()
# Out:
# True
