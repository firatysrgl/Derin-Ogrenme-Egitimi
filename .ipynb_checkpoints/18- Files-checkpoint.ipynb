# %%
# %%writefile myfile.txt
# test1
# test2
# test3
# Out:
# Writing myfile.txt

# %%
myFile = open("myfile.txt")

# %%
type(myFile)
# Out:
# _io.TextIOWrapper

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3\n'

# %%
myFile.read()
# Out:
# ''

# %%
myFile.seek(0)
# Out:
# 0

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3\n'

# %%
myFile.close()

# %%
with open ("myfile.txt") as myFile:
    myText=myFile.read()     # Dosya kullanımlarında "with" anahtar kelimesini kullanırsak tekrar tekrar başa dönmeler yapmamıza gerek kalmaz

# %%
myText
# Out:
# 'test1\ntest2\ntest3\n'

# %%
myText
# Out:
# 'test1\ntest2\ntest3\n'

# %%
with open ("myfile.txt",mode="w") as myNewFile:
    myNewFile.write("test4")

# %%
myNewFile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='w' encoding='cp1254'>

# %%
with open ("myfile.txt",mode="r") as myFile2:
    myText = myFile2.read()

# %%
myText
# Out:
# 'test4'

# %% [markdown]
# # w -> write, r -> read, a -> append

# %%
with open ("myfile.txt",mode="w") as myNewFile3:
    myNewFile3.write("test5")

# %%
with open ("myfile.txt",mode="r") as myFile4:
    myText = myFile4.read()

# %%
myText
# Out:
# 'test5'
