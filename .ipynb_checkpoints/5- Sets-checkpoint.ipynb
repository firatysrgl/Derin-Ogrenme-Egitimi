# %%
# unique elements (Tekil Eleman) ; unordered (Sıra Önemsiz)

# %%
myList = [10,20,30,10,20,40,10,20,40]

# %%
len(myList)
# Out:
# 9

# %%
myList
# Out:
# [10, 20, 30, 10, 20, 40, 10, 20, 40]

# %%
mySet=set(myList) # Tekrarlanan ifadeleri almaz ve sıraya sokar

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet = {10,20,30,10,20,40,10,20,40,50,50,60,50}

# %%
mySet
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
mySet.add (10) # aynı değeri tekrar ekleyemeyiz

# %%
mySet
# Out:
# {0, 10, 20, 30, 40, 50, 60}

# %%
mySet.add (0) # farklı değerleri ekleyebiliriz

# %%
mySet
# Out:
# {0, 10, 20, 30, 40, 50, 60}

# %%
mySet={10,20,30,40,50,}

# %%
mySet2={30,40,50,10,60,70}

# %%
mySet.union(mySet2) # iki farklı sette dahi aynı değerler olursa yine 1 tanesini tek kullanır
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
countryList= ["tr","de","fr","fr","fr","tr","nl","de","de"]

# %%
len(countryList)
# Out:
# 9

# %%
set(countryList)
# Out:
# {'de', 'fr', 'nl', 'tr'}

# %%
len(set(countryList))
# Out:
# 4

# %%
emptyList = []

# %%
emptyList.append (1088)
emptyList.append (102)
emptyList.append (100)
emptyList.append (500)

# %%
emptyList
# Out:
# [1088, 102, 100, 500]

# %%
emptySet ={}

# %%
type(emptySet)
# Out:
# dict

# %%
emptySet = set()

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add (10)
emptySet.add (10)
emptySet.add (10)
emptySet.add (20)
emptySet.add (30)

# %%
emptySet
# Out:
# {10, 20, 30}
