# %%
# key - value pairing

# %%
fruit_list = ["banana","apple"]

# %%
calorie_list = [100,150]

# %%
fruit_list [0]
# Out:
# 'banana'

# %%
calorie_list [0]
# Out:
# 100

# %%
fitness_dictionary = {"banana":100,"apple":150}

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
# fitness_dictionary [0] burada artık index mantığı çalışmaz .

# %%
fitness_dictionary ["apple"] # direk kelime bazlı arama yaptırız
# Out:
# 150

# %%
fitness_dictionary.keys()
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %%
list (fitness_dictionary.values())
# Out:
# [100, 150]

# %%
type (list (fitness_dictionary.values()))
# Out:
# list

# %%
fitness_dictionary["apple"] = 200 # mevcut değeri değiştirme

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 200}

# %%
fitness_dictionary ["melon"] = 320 # yeni bir değer ekleme

# %%
fitness_dictionary
# Out:
# {'banana': 100, 'apple': 200, 'melon': 320}

# %%
fitness_dictionary.get("appl",0) # list içinde değer girilen değer yoksa 0 çıkaracak bunu yapmamızdaki amaç yanlış bir değer girildiğinde hata ile karşılaşmamak
# Out:
# 0

# %%
last_dictionary ={"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}}

# %%
last_dictionary["k2"][3]
# Out:
# 40

# %%
last_dictionary ["k4"] ["b"]
# Out:
# 200
