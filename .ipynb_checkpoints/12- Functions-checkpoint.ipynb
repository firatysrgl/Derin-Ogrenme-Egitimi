# %%
# Method & Function

# %%
my_name = "Firat"

# %%
my_name.upper()
# Out:
# 'FIRAT'

# %%
# functions

# %%
def hello_python ():
    print ("Hello")
    print ("Python")

# %%
hello_python
# Out:
# <function __main__.hello_python()>

# %%
hello_python()
# Out:
# Hello
# Python

# %%
# İnput

# %%
def hello_name(name):
    print("hello")
    print (name)

# %%
hello_name ("Fırat")
# Out:
# hello
# Fırat

# %%
def sum_example(num1, num2):
    print (num1+num2)

# %%
sum_example (5,10)
# Out:
# 15

# %%
# Return

# %%
def summation (num1,num2,num3):
    print (num1+num2+num3)

# %%
summation (10,20,555)
# Out:
# 585

# %%
x=summation(10,20,555)
# Out:
# 585

# %%
x

# %%
print(x)
# Out:
# None

# %%
type(x)
# Out:
# NoneType

# %%
def return_summation (num1,num2,num3):
    return num1+num2+num3

# %%
return_summation
# Out:
# <function __main__.return_summation(num1, num2, num3)>

# %%
return_summation(10,20,555)
# Out:
# 585

# %%
x = return_summation(10,20,555)

# %%
x
# Out:
# 585
