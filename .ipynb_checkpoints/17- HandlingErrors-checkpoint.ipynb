# %%
age = input ("enter age: ")
# Out:
# enter age:  10

# %%
age
# Out:
# '10'

# %%
int (age)*2
# Out:
# 20

# %%
# try - expect

# %%
while 1==1:
    try:
        myAge = int (input("enter age: "))
        print (myAge*2)
        break
    except:
        print ("enter your age !!!")
    else:
        print("else executed")
    finally:
        print("finally")
# Out:
# enter age:  firat
# enter your age !!!
# finally
# enter age:  10
# 20
# finally
