# %%
myList=[10,20,"a","b",3.14]

# %%
myList[0]
# Out:
# 10

# %%
myList[0]= 100

# %%
myList
# Out:
# [100, 20, 'a', 'b', 3.14]

# %%
#Tuple

# %%
myTuple = (10,20,"a","b" ,3.14)

# %%
# myTuple de liste mantığında olduğu gibi sonradan ekleme çıkarma yapamayız

# %%
myTuple.count(10) # bu şekilde değer aratabilirz.
# Out:
# 1

# %%
myTuple.index (20) # birde değerin indexini aratabiliriz.
# Out:
# 1

# %%
resultTuple=(500,600,700,800)

# %%
myList= list (resultTuple)

# %%
myList
# Out:
# [500, 600, 700, 800]

# %%
type(myList)
# Out:
# list
