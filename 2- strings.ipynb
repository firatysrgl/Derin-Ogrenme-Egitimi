# %%
"hello world"
# Out:
# 'hello world'

# %%
print ("hello")
# Out:
# hello

# %%
name="fırat yunus"

# %%
type(name)
# Out:
# str

# %%
name.capitalize()
# Out:
# 'Fırat yunus'

# %%
name
# Out:
# 'fırat yunus'

# %%
nameUpper = name.upper ()

# %%
nameUpper
# Out:
# 'FIRAT YUNUS'

# %%
len(name) # len = length içinde bulunan değerin karakter sayısını verir
# Out:
# 11

# %%
print ("Fırat \nYunus")   #  \n -> new line anlamına gelir yeni satıra geçerir sonraki değeri
# Out:
# Fırat
# Yunus

# %% [markdown]
# # İndex

# %%
myString = "hello python"

# %%
myString [4]
# Out:
# 'o'

# %%
# çıktı olarak "o" çıktı ama "hello" da "o" 5. karakternormalde ama index değerleri 0 ile başlar

# %%
myString [0]
# Out:
# 'h'

# %%
myString [5]
# Out:
# ' '

# %%
barcode ="ABC1234567890"

# %%
barcode[0] + barcode[1] # Stringlerde toplama işlemi iki değeri yan yana yazmaya yarar
# Out:
# 'AB'

# %%
barcode [0]+ barcode [1]+ barcode[-1]+ barcode[-2]
# Out:
# 'AB09'

# %%
barcode
# Out:
# 'ABC1234567890'

# %%
#barcode[starting index:stopping index:stepping size ]

# %%
barcode[3::] # 3. index ten başlayıp alır
# Out:
# '1234567890'

# %%
barcode [:3:] # 3. index e kadar alır
# Out:
# 'ABC'

# %%
barcode [::2] # bu durumda da index değerlerini kaçar tane atlayacağını belirler
# Out:
# 'AC24680'

# %%
barcode [4:11:2]
# Out:
# '2468'

# %%
barcode
# Out:
# 'ABC1234567890'

# %%
barcode[::-1] # size ye (atlama değer kısmına ) "-1" değeri girilirse değer tersten çıktı olarak verir
# Out:
# '0987654321CBA'

# %%
name.index("a") # verilen değerde istenilen değerin kaçınıcı index te olduğunu belirtir
# Out:
# 3
