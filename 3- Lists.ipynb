# %%
myString = "Hello Python"

# %%
myString.split ()
# Out:
# ['Hello', 'Python']

# %%
type (myString)
# Out:
# str

# %%
type (myString.split())
# Out:
# list

# %%
myString
# Out:
# 'Hello Python'

# %%
myString [0]
# Out:
# 'H'

# %%
# myString [0]= "a"

# %%
# immutable tek bir index değerini değiştiremeyiz ama komple myString değerini değiştirebilirz .

# %%
myString = "oldu"

# %%
myString
# Out:
# 'oldu'

# %% [markdown]
# # List

# %%
myList =[10,20,30]

# %%
type (myList)
# Out:
# list

# %%
x =10
y=20
z=30

# %%
myList2=[x,y,z]

# %%
myList2
# Out:
# [10, 20, 30]

# %%
type (myList2)
# Out:
# list

# %%
myList[2]=50

# %%
myList
# Out:
# [10, 20, 50]

# %%
#mutable List lerde index bazında değer değiştirebiliyoruz

# %%
len(myList)
# Out:
# 3

# %%
myList[len(myList)-1] # list içindeki son index değerini verir
# Out:
# 50

# %%
myList[-1] # kolay olarak böylede list içindeki son index değerini verir
# Out:
# 50

# %%
myList[-3] # index değeri olarak - ile arama yapıldığında tersten index değerlerini okuyp çıktı olarak verir.
# Out:
# 10

# %%
myList[0] # - ile arama yaptığımızda 0 tek değerlik aldığı için geriden gelirken ( - ile index araması yaparken ) -1 ile başlanır
# Out:
# 10

# %%
# Liste Özellikleri

# %%
myList.append (80) #Tanımlı bir  List içine En sona yeni bir değer atamaızı sağlar

# %%
myList
# Out:
# [10, 20, 50, 80]

# %%
myList.append(1)

# %%
myList
# Out:
# [10, 20, 50, 80, 1]

# %%
len (myList)
# Out:
# 5

# %%
myList.count (80)# Tanımlı olan List içinde parantez içindeki değerin kaç tane olduğunu verir
# Out:
# 1

# %%
myList.append (1)

# %%
myList.append (1)

# %%
myList
# Out:
# [10, 20, 50, 80, 1, 1, 1]

# %%
myList.count(1)
# Out:
# 3

# %%
myList.index(1) # Tanımlı olan List içinde parantez içindeki değerin [ baştan ilk önce ] hangi indexte olduğunu verir
# Out:
# 4

# %%
myList
# Out:
# [10, 20, 50, 80, 1, 1, 1]

# %%
myList.insert(5,25) # parantez içinde önce değişitrilmek istenen index numarası daha sonra atanacak değer verilir

# %%
myList
# Out:
# [10, 20, 50, 80, 1, 25, 1, 1]

# %%
myList.insert (6,"Fırat Yunus")

# %%
myList
# Out:
# [10, 20, 50, 80, 1, 25, 'Fırat Yunus', 1, 1]

# %%
len(myList)
# Out:
# 9

# %%
## insert verilen indexe yeni değeri atar ve index numaralarını kesilen yerden sağa doğru olacak şekilde 1 adet kaydırır.

# %%
myList.pop() # list teki son index değerini siler
# Out:
# 1

# %%
myList
# Out:
# [10, 20, 50, 80, 25, 'Fırat Yunus']

# %%
# myList.remove(1) # parantez içindeki değeri bulduğu ilk indexten siler

# %%
myList
# Out:
# [10, 20, 50, 80, 25, 'Fırat Yunus']

# %%
myList.reverse() # List i tersine çevirir

# %%
myList
# Out:
# ['Fırat Yunus', 25, 80, 50, 20, 10]

# %%
# myList.sort() sort list değerlerini küçükten büyüğe sıralar

# %%
x= input ("enter x :")
# Out:
# enter x : 521

# %%
x
# Out:
# '521'

# %%
type(x)
# Out:
# str

# %%
y=input("enter y:")
# Out:
# enter y: 45

# %%
z=input ("enter z:")
# Out:
# enter z: 98

# %%
inputList=[x,y,z]

# %%
inputList
# Out:
# ['521', '45', '98']

# %%
int (inputList[1])*2
# Out:
# 90

# %%
list1=[10,20,30]
list2=[90,50,60]

# %%
list1+list2 # Stringte olduğu gibi yan yana ekler
# Out:
# [10, 20, 30, 90, 50, 60]

# %%
list1*2 # list1 2 defa yan yana yazdırır
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
mixedList=["FIRAT",105,3694,3.4545]

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[3])
# Out:
# float

# %% [markdown]
# # NestedList

# %%
myNestedList=[1,2,3,854,[2,36,84,],["Fırat Yunus"],9]

# %%
myNestedList
# Out:
# [1, 2, 3, 854, [2, 36, 84], ['Fırat Yunus'], 9]

# %%
myNestedList[3]
# Out:
# 854

# %%
myNestedList[4]
# Out:
# [2, 36, 84]

# %%
myNestedList[5]
# Out:
# ['Fırat Yunus']

# %%
myNestedList[6]
# Out:
# 9

# %%
smallList=myNestedList[4]

# %%
smallList
# Out:
# [2, 36, 84]

# %%
myNestedList[4][2]
# Out:
# 84

# %%
len(myNestedList)
# Out:
# 7

# %%
myList
# Out:
# ['Fırat Yunus', 25, 80, 50, 20, 10]

# %%
myList[1::]
# Out:
# [25, 80, 50, 20, 10]

# %%
myList[:3:]
# Out:
# ['Fırat Yunus', 25, 80]

# %%
myList[::2]
# Out:
# ['Fırat Yunus', 80, 20]
